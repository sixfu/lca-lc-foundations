# %% [markdown]
# ## Without web search

# %%
from dotenv import load_dotenv

load_dotenv(override=True)
# Out:
# True

# %%
from langchain.agents import create_agent

agent = create_agent(
    model="gpt-5-nano"
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="How up to date is your training knowledge?")

response = agent.invoke(
    {"messages": [question]}
)

# %%
print(response['messages'][-1].content)
# Out:
# My training data goes up to June 2024. I don’t have real-time internet access unless a browsing tool is enabled in your session, so I may not know about events, publications, or releases after that date. If you need the latest information, I can help you craft effective search queries or, if browsing is available, I can look it up. You can also paste newer information here and I’ll use it in our conversation.

# %% [markdown]
# ## Add web search tool

# %%
from langchain.tools import tool
from typing import Dict, Any
from tavily import TavilyClient

tavily_client = TavilyClient()

@tool
def web_search(query: str) -> Dict[str, Any]:

    """Search the web for information"""

    return tavily_client.search(query)

web_search.invoke("Who is the current mayor of San Francisco?")
# Out:
# {'query': 'Who is the current mayor of San Francisco?',
#  'follow_up_questions': None,
#  'answer': None,
#  'images': [],
#  'results': [{'url': 'https://en.wikipedia.org/wiki/Mayor_of_San_Francisco',
#    'title': 'Mayor of San Francisco - Wikipedia',
#    'content': 'The current mayor is Democrat Daniel Lurie.',
#    'score': 0.9994253,
#    'raw_content': None},
#   {'url': 'https://apnews.com/article/san-francisco-new-mayor-liberal-city-81ea0a7b37af6cbb68aea7ef5cc6a4f0',
#    'title': "San Francisco's new mayor is starting to unite the fractured city",
#    'content': 'San Francisco Mayor Daniel Lurie, a political newcomer and Levi Strauss heir, has marked his first 100 days with a hands-on, business-friendly approach.',
#    'score': 0.9993538,
#    'raw_content': None},
#   {'url': 'https://www.sf.gov/departments--office-mayor',
#    'title': 'Office of the Mayor - SF.gov',
#    'content': 'Daniel Lurie is the 46th Mayor of the City and County of San Francisco.',
#    'score': 0.99620515,
#    'raw_content': None},
#   {'url': 'https://www.youtube.com/watch?v=Qvl6AMoZCoI',
#    'title': 'San Francisco Mayor-elect Daniel Lurie on transforming the city',
#    'content': "In a CNBC exclusive, San Francisco's new Mayor-elect Daniel Lurie sits down with Kate Rogers to talk about bringing remote workers back,",
#    'score': 0.9921233,
#    'raw_content': None},
#   {'url': 'https://www.politico.com/news/magazine/2025/02/23/daniel-lurie-san-francisco-mayor-00205527',
#    'title': 'Mayor Lurie Tries to Bloomberg-ize San Francisco - POLITICO',
#    'content': "SAN FRANCISCO — Daniel Lurie began the morning of his inauguration as this city's new mayor last month at a soup kitchen before walking with",
#    'score': 0.9890131,
#    'raw_content': None}],
#  'response_time': 0.58,
#  'request_id': '5d254f4b-225c-4cb8-9e0d-ca827bbd9307'}

# %%
web_search.invoke("Who is the current mayor of San Francisco? when he/she was elected?")
# Out:
# {'query': 'Who is the current mayor of San Francisco? when he/she was elected?',
#  'follow_up_questions': None,
#  'answer': None,
#  'images': [],
#  'results': [{'url': 'https://en.wikipedia.org/wiki/Daniel_Lurie',
#    'title': 'Daniel Lurie - Wikipedia',
#    'content': 'Daniel Lawrence Lurie (born 4 February 1977) is an American politician and philanthropist who is the 46th and current mayor of San Francisco, serving since 2025',
#    'score': 0.83093774,
#    'raw_content': None},
#   {'url': 'https://www.cbsnews.com/sanfrancisco/news/san-francisco-mayor-elect-daniel-lurie-claims-victory-outlines-vision-for-city/',
#    'title': 'San Francisco Mayor-elect Daniel Lurie claims victory ... - CBS News',
#    'content': "San Francisco's Mayor-elect Daniel Lurie declared victory Friday morning as he addressed the city for the first time since incumbent Mayor London Breed",
#    'score': 0.71995544,
#    'raw_content': None},
#   {'url': 'https://www.facebook.com/TheGenesisPrize/posts/last-week-san-francisco-elected-daniel-lurie-as-its-mayor-lurie-is-the-fourth-je/960389832779590/',
#    'title': 'Last week, San Francisco elected Daniel Lurie as its mayor. Lurie is ...',
#    'content': 'Last week, San Francisco elected Daniel Lurie as its mayor. Lurie is the fourth Jewish mayor of San Francisco and is the first political',
#    'score': 0.71137124,
#    'raw_content': None},
#   {'url': 'https://www.youtube.com/watch?v=G5kDdDF9NW4',
#    'title': "Daniel Lurie inaugurated as San Francisco's 46th mayor: FULL VIDEO",
#    'content': "Change in leadership has come to San Francisco on Wednesday as Daniel Lurie was sworn in as the city's new mayor. https://abc7ne.ws/4fShIPM",
#    'score': 0.62248284,
#    'raw_content': None},
#   {'url': 'https://www.politico.com/news/magazine/2025/02/23/daniel-lurie-san-francisco-mayor-00205527',
#    'title': 'Mayor Lurie Tries to Bloomberg-ize San Francisco - POLITICO',
#    'content': "SAN FRANCISCO — Daniel Lurie began the morning of his inauguration as this city's new mayor last month at a soup kitchen before walking with",
#    'score': 0.5482629,
#    'raw_content': None}],
#  'response_time': 0.9,
#  'request_id': '2268ea57-67c2-4bf4-9aa0-6b963eb28069'}

# %%
agent = create_agent(
    model="gpt-5-nano",
    tools=[web_search]
)

question = HumanMessage(content="Who is the current mayor of San Francisco? When he/she was elected")

response = agent.invoke(
    {"messages": [question]}
)

# %%
from pprint import pprint

pprint(response['messages'])
# Out:
# [HumanMessage(content='Who is the current mayor of San Francisco? When he/she was elected', additional_kwargs={}, response_metadata={}, id='d2d0b9e5-e19c-4710-b675-c722cc0086ca'),
#  AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 551, 'prompt_tokens': 138, 'total_tokens': 689, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 512, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-Cv9F9O7v1ndBO4w1ykki5yR94WnOR', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019b954a-bfbb-73d1-8c86-87ac05896003-0', tool_calls=[{'name': 'web_search', 'args': {'query': 'Who is the current mayor of San Francisco and when was she elected London Breed elected date'}, 'id': 'call_vRNWktjOVjkxpkrdRPUOkj3s', 'type': 'tool_call'}], usage_metadata={'input_tokens': 138, 'output_tokens': 551, 'total_tokens': 689, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 512}}),
#  ToolMessage(content='{"query": "Who is the current mayor of San Francisco and when was she elected London Breed elected date", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.sf.gov/profile--london-breed", "title": "London Breed - SF.gov", "content": "London Nicole Breed was the 45th mayor of the City and County of San Francisco from 2018 until January 2025.", "score": 0.8033131, "raw_content": null}, {"url": "https://mtc.ca.gov/sites/default/files/London_Breed_bio.pdf", "title": "[PDF] London Breed Mayor | City and County of San Francisco", "content": "Prior to being elected by voters in the June 2018 election, she served as Acting Mayor, leading San Francisco following the sudden passing of Mayor Edwin Lee.", "score": 0.72814995, "raw_content": null}, {"url": "https://ballotpedia.org/London_Breed", "title": "London Breed - Ballotpedia", "content": "Breed ran for re-election for Mayor of San Francisco in California. She lost in the general election on November 5, 2024. Breed earned a B.A. in political", "score": 0.71088976, "raw_content": null}, {"url": "https://www.cnn.com/2018/06/13/politics/san-francisco-mayor-election-results", "title": "London Breed is elected mayor of San Francisco | CNN Politics", "content": "London Breed reached the milestone on Wednesday, when her opponent conceded a tight mayoral race. Breed will serve until 2020, finishing the", "score": 0.6701125, "raw_content": null}, {"url": "https://www.nytimes.com/2024/11/07/us/politics/san-francisco-mayor-breed-lurie.html", "title": "London Breed Concedes San Francisco Mayor Race to Daniel Lurie", "content": "Mayor London Breed acknowledged on Thursday that Daniel Lurie, a first-time candidate, would succeed her in office.", "score": 0.5515985, "raw_content": null}], "response_time": 1.01, "request_id": "6e3b604e-4bae-496f-a80c-db50376c5d8c"}', name='web_search', id='6bee0ea2-df25-4a16-a2fa-81ae2c24e8fc', tool_call_id='call_vRNWktjOVjkxpkrdRPUOkj3s'),
#  AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 684, 'prompt_tokens': 698, 'total_tokens': 1382, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 640, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-Cv9FHJAiSLthQ9vNxbOa66sekx5Ge', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019b954a-df7b-7150-906e-6384f022df21-0', tool_calls=[{'name': 'web_search', 'args': {'query': 'Daniel Lurie sworn in as mayor San Francisco January 2025 date sworn in January 2025 SF mayor'}, 'id': 'call_mLSxSzu89A5stuydKqATeY7E', 'type': 'tool_call'}], usage_metadata={'input_tokens': 698, 'output_tokens': 684, 'total_tokens': 1382, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 640}}),
#  ToolMessage(content='{"query": "Daniel Lurie sworn in as mayor San Francisco January 2025 date sworn in January 2025 SF mayor", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.youtube.com/watch?v=IqJgUs-Y6X0", "title": "Levi Strauss heir Daniel Lurie sworn in as San Francisco\'s new mayor", "content": "Levi Strauss heir Daniel Lurie sworn in as San Francisco\'s new mayor\\nAP Archive\\n5900000 subscribers\\n6 likes\\n291 views\\n14 Jan 2025\\n(9 Jan 2025) \\r\\nFOR CLEAN VERSION SEE STORY NUMBER: 4545614\\r\\n\\r\\nASSOCIATED PRESS\\r\\nSan Francisco - 8 January 2025\\r\\n1. Mayor Daniel Lurie signs oath of office surrounded by family inside City Hall\\r\\n2. Lurie takes the oath of office at ceremony outside City Hall\\r\\n3. Wide shot of City Hall with Daniel Lurie speaking at inauguration\\r\\n4. SOUNDBITE (English) Daniel Lurie, San Francisco Mayor:\\r\\n\\"Today marks the beginning of a new era of accountability and change at City Hall, one that, above all else, serves you the people of San Francisco. That begins now.\\"\\r\\n5. Supporters listen to Lurie speech\\r\\n6. SOUNDBITE (English) Daniel Lurie, San Francisco Mayor:\\r\\n\\"It is the greatest honor of my life to serve as your mayor at this critical moment in our history. I\'m asking all of you, every single one of you to join me in reclaiming our place as the greatest city in the world with a new era of accountability, service and change. It\'s time to roll up our sleeves and get to work, San Francisco. Thank you very much.\\"\\r\\nSTORYLINE:\\r\\nLevi Strauss heir Daniel Lurie was sworn in Wednesday as San Francisco’s 46th mayor at an inauguration ceremony outside City Hall.\\r\\n\\r\\nLurie, a philanthropist who has never held public office, pledged to restore San Francisco\'s stature as one of the world\'s great cities. \\r\\n\\r\\n\\"I\'m asking all of you, every single one of you, to join me in reclaiming our place as the greatest city in the world with a new era of accountability, service and change. It\'s time to roll up our sleeves and get to work, San Francisco,\\" Lurie said during his speech to supporters.\\r\\n\\r\\nLurie replaces London Breed, who became acting mayor when her predecessor Ed Lee died in 2017. She became mayor during a special election in June 2018. She\'s the first Black woman to hold the office.\\r\\n\\r\\nBreed’s fellow Democratic challengers slammed her administration for not doing enough as homeless tent encampments, open-air drug use and brazen retail theft proliferated during her six years in office.\\r\\n\\r\\nLurie, 47, a city native from a storied family, pledged to bring accountability and public service back to City Hall. He founded Tipping Point Community, which says it has invested more than $400 million since 2005 in programs to help people with housing, education and early childhood. \\r\\n\\r\\n===========================================================\\r\\n\\r\\nClients are reminded to adhere to all listed restrictions and to check the terms of their licence agreements. For further assistance, please contact the AP Archive on: Tel +44(0)2074827482 Email: info@aparchive.com.\\r\\n\\r\\nFind out more about AP Archive: http://www.aparchive.com/HowWeWork \\r\\nTwitter: https://twitter.com/AP_Archive \\r\\nFacebook: https://www.facebook.com/APArchives \u200b\u200b\\r\\nInstagram: https://www.instagram.com/APNews/\\r\\n\\r\\n\\r\\nYou can license this story through AP Archive: http://www.aparchive.com/metadata/youtube/d12b34634f1f43cb9245d0a49aa78fc9\\n\\n", "score": 0.9404462, "raw_content": null}, {"url": "https://www.sf.gov/information--mayoral-inauguration-and-public-activities", "title": "Mayoral inauguration and public activities - SF.gov", "content": "# Mayoral inauguration and public activities. On January 8, 2025, the 46th Mayor of San Francisco and newly elected Supervisors will be sworn into office. ## City Hall. City Hall will remain open with regular business hours.  ...
#  AIMessage(content='Daniel Lurie is the current mayor of San Francisco. He was elected in the November 5, 2024 general election and was sworn in on January 8, 2025 as the city’s 46th mayor.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 1079, 'prompt_tokens': 2601, 'total_tokens': 3680, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 1024, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-Cv9FQ1SLDSvphQ4tgb5HeDGPE4Zme', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b954b-01b7-71c0-a7e6-ca775b745abe-0', usage_metadata={'input_tokens': 2601, 'output_tokens': 1079, 'total_tokens': 3680, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 1024}})]

# %% [markdown]
# trace: https://smith.langchain.com/public/59432173-0dd6-49e8-9964-b16be6048426/r
