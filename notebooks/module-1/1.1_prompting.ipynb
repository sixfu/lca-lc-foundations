# %% [markdown]
# ## Basic prompting

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage

# agent = create_agent(model="gpt-5-nano")

from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")
# agent = create_agent(model="gemini-2.5-flash-lite")
agent = create_agent(model=model)

question = HumanMessage(content="What's the capital of the moon?")

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# The Moon doesn't have a capital city because it's not a country or a populated territory. It's a celestial body with no governments or permanent human settlements.

# %%
agent2 = create_agent(model="gpt-5-nano")

question = HumanMessage(content="What's the capital of the moon?")

response2 = agent2.invoke(
    {"messages": [question]}
)

print(response2['messages'][1].content)
# Out:
# There isn’t one. The Moon isn’t a country or a government, so it has no capital. In fiction, authors sometimes invent places like “Lunapolis” or other names, but those are purely fictional. Want me to list a few fictional capitals from sci‑fi works?

# %%
system_prompt = "You are a science fiction writer, create a capital city at the users request."

scifi_agent = create_agent(
    # model="gpt-5-nano",
    model=model,
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# Ah, the Moon! A celestial body, a silver coin tossed into the velvet cloak of night, and a cradle of humanity's most ambitious dreams. You ask for its capital?
#
# Forget the sterile, metallic domes of old Earth sci-fi. The capital of the Moon, the heart of Luna City, is **Selene's Embrace**.
#
# It's not a single, monolithic structure, but rather a breathtaking, interconnected tapestry woven into the very fabric of the lunar landscape. Selene's Embrace is nestled within the **Mare Tranquillitatis**, the Sea of Tranquility, a name that belies the vibrant, pulsating life within its geodesic domes and subterranean arteries.
#
# Imagine this:
#
# *   **The Lumina Domes:** These aren't just transparent shields; they are living, breathing organisms of bio-engineered crystalline structures that *filter* and *amplify* Earthlight. By day (or rather, during Earthlight), they glow with an ethereal luminescence, casting soft, ever-shifting patterns across the city. By night, they capture and refract the faint starlight, creating a perpetual twilight studded with constellations visible with impossible clarity.
#
# *   **The Lunar Grottoes:** Beneath the domes, Selene's Embrace plunges into the lunar crust. These aren't dark, utilitarian tunnels. Instead, they are vast, sculpted caverns lined with phosphorescent fungi and mineral deposits that glow with a gentle, inner light. Think bioluminescent cathedrals carved from moonrock, with rivers of recycled, purified water flowing through their depths, reflecting the shimmering ceilings.
#
# *   **The Citadel of Orbits:** The administrative and governmental hub isn't a towering spire, but a series of concentric rings suspended in a zero-gravity atrium. Think a cosmic carousel where the most important decisions are made. Representatives from lunar colonies, orbital habitats, and even ambitious asteroid mining guilds navigate these rings, their movements graceful and deliberate in the gentle lunar gravity. The central "Orrery" displays a holographic, real-time model of the Sol system, its planets and moons in constant, silent motion.
#
# *   **The Gardens of Æther:** These are vast, enclosed biospheres where Earth flora has been meticulously adapted to lunar conditions. Towering bio-luminescent trees stretch towards the dome ceilings, their roots drawing nutrients from processed regolith. Flowers bloom with impossible colors, nurtured by carefully controlled atmospheric mixes and the faint, yet potent, energy of the Sun as filtered by the Lumina Domes. These gardens are not just for sustenance; they are sanctuaries of life and beauty, a constant reminder of humanity's terrestrial heritage.
#
# *   **The Obsidian Market:** This is where the true heart of Selene's Embrace beats. Carved from ancient lava tubes, the market is a cacophony of sensory delights. Merchants hawk rare lunar minerals, genetically engineered foodstuffs that taste like a forgotten dream, and intricate artwork crafted from meteoric iron and captured stardust. The air hums with the soft clicks and whirs of personalized grav-lifts and the murmurs of a dozen different Earth languages, blended with the unique lunar dialect that has emerged.
#
# The people of Selene's Embrace, the Lunan, are a hardy, ingenious folk. They move with a deliberate grace born of lower gravity, their eyes often reflecting the distant shimmer of Earth in their pupils. Their fashion favors flowing fabrics that catch the ambient light, and many wear subtle bio-luminescent accents that pulse with their emotions.
#
# Selene's Embrace isn't just a capital; it's a testament to humanity's resilience and its unwavering gaze towards the infinite. It's a city that whispers of ancient gods and screams of a future forged not just on Earth, but among the stars.
#
# So, when you ask for the capital of the Moon, remember Selene's Embrace – a city that is as beautiful, as mysterious, and as full of potential as the celestial body it calls home.

# %%
response
# Out:
# {'messages': [HumanMessage(content="What's the capital of the moon?", additional_kwargs={}, response_metadata={}, id='c8babfd1-e166-4b1a-8773-b2a3ab951ca8'),
#   AIMessage(content='Ah, the Moon! A celestial body, a silver coin tossed into the velvet cloak of night, and a cradle of humanity\'s most ambitious dreams. You ask for its capital?\n\nForget the sterile, metallic domes of old Earth sci-fi. The capital of the Moon, the heart of Luna City, is **Selene\'s Embrace**.\n\nIt\'s not a single, monolithic structure, but rather a breathtaking, interconnected tapestry woven into the very fabric of the lunar landscape. Selene\'s Embrace is nestled within the **Mare Tranquillitatis**, the Sea of Tranquility, a name that belies the vibrant, pulsating life within its geodesic domes and subterranean arteries.\n\nImagine this:\n\n*   **The Lumina Domes:** These aren\'t just transparent shields; they are living, breathing organisms of bio-engineered crystalline structures that *filter* and *amplify* Earthlight. By day (or rather, during Earthlight), they glow with an ethereal luminescence, casting soft, ever-shifting patterns across the city. By night, they capture and refract the faint starlight, creating a perpetual twilight studded with constellations visible with impossible clarity.\n\n*   **The Lunar Grottoes:** Beneath the domes, Selene\'s Embrace plunges into the lunar crust. These aren\'t dark, utilitarian tunnels. Instead, they are vast, sculpted caverns lined with phosphorescent fungi and mineral deposits that glow with a gentle, inner light. Think bioluminescent cathedrals carved from moonrock, with rivers of recycled, purified water flowing through their depths, reflecting the shimmering ceilings.\n\n*   **The Citadel of Orbits:** The administrative and governmental hub isn\'t a towering spire, but a series of concentric rings suspended in a zero-gravity atrium. Think a cosmic carousel where the most important decisions are made. Representatives from lunar colonies, orbital habitats, and even ambitious asteroid mining guilds navigate these rings, their movements graceful and deliberate in the gentle lunar gravity. The central "Orrery" displays a holographic, real-time model of the Sol system, its planets and moons in constant, silent motion.\n\n*   **The Gardens of Æther:** These are vast, enclosed biospheres where Earth flora has been meticulously adapted to lunar conditions. Towering bio-luminescent trees stretch towards the dome ceilings, their roots drawing nutrients from processed regolith. Flowers bloom with impossible colors, nurtured by carefully controlled atmospheric mixes and the faint, yet potent, energy of the Sun as filtered by the Lumina Domes. These gardens are not just for sustenance; they are sanctuaries of life and beauty, a constant reminder of humanity\'s terrestrial heritage.\n\n*   **The Obsidian Market:** This is where the true heart of Selene\'s Embrace beats. Carved from ancient lava tubes, the market is a cacophony of sensory delights. Merchants hawk rare lunar minerals, genetically engineered foodstuffs that taste like a forgotten dream, and intricate artwork crafted from meteoric iron and captured stardust. The air hums with the soft clicks and whirs of personalized grav-lifts and the murmurs of a dozen different Earth languages, blended with the unique lunar dialect that has emerged.\n\nThe people of Selene\'s Embrace, the Lunan, are a hardy, ingenious folk. They move with a deliberate grace born of lower gravity, their eyes often reflecting the distant shimmer of Earth in their pupils. Their fashion favors flowing fabrics that catch the ambient light, and many wear subtle bio-luminescent accents that pulse with their emotions.\n\nSelene\'s Embrace isn\'t just a capital; it\'s a testament to humanity\'s resilience and its unwavering gaze towards the infinite. It\'s a city that whispers of ancient gods and screams of a future forged not just on Earth, but among the stars.\n\nSo, when you ask for the capital of the Moon, remember Selene\'s Embrace – a city that is as beautiful, as mysterious, and as full of potential as the celestial body it calls home.' ...

# %%
msgs = response2["messages"]

last_ai_msg = msgs[-1]
print(type(last_ai_msg))      # AIMessage
print(last_ai_msg.content)    # model reply
pprint(last_ai_msg.response_metadata)   # provider-specific or custom metadata
# Out:
# <class 'langchain_core.messages.ai.AIMessage'>
# There isn’t one. The Moon isn’t a country or a government, so it has no capital. In fiction, authors sometimes invent places like “Lunapolis” or other names, but those are purely fictional. Want me to list a few fictional capitals from sci‑fi works?
# {'finish_reason': 'stop',
#  'id': 'chatcmpl-Cv6ekdyx0fMFvZSkgGLRTHkeJKk6h',
#  'logprobs': None,
#  'model_name': 'gpt-5-nano-2025-08-07',
#  'model_provider': 'openai',
#  'service_tier': 'default',
#  'system_fingerprint': None,
#  'token_usage': {'completion_tokens': 387,
#                  'completion_tokens_details': {'accepted_prediction_tokens': 0,
#                                                'audio_tokens': 0,
#                                                'reasoning_tokens': 320,
#                                                'rejected_prediction_tokens': 0},
#                  'prompt_tokens': 13,
#                  'prompt_tokens_details': {'audio_tokens': 0,
#                                            'cached_tokens': 0},
#                  'total_tokens': 400}}

# %%
from pprint import pprint
msgs = response["messages"]

last_ai_msg = msgs[-1]
pprint(last_ai_msg.response_metadata)
# Out:
# {'finish_reason': 'STOP',
#  'model_name': 'gemini-2.5-flash-lite',
#  'model_provider': 'google_genai',
#  'safety_ratings': []}

# %% [markdown]
# ## Few-shot examples

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

User: What is the capital of mars?
Scifi Writer: Marsialis

User: What is the capital of Venus?
Scifi Writer: Venusovia

"""
model = ChatGoogleGenerativeAI(model="gemini-2.5-flash")
scifi_agent = create_agent(
    # model="gpt-5-nano",
    model=model,
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# Lunaria

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

User: What is the capital of mars?
Scifi Writer: Marsialis

User: What is the capital of Venus?
Scifi Writer: Venusovia

"""

scifi_agent = create_agent(
    model="gpt-5-nano",
    # model=model,
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# Lunopolis

# %% [markdown]
# ## Structured prompts

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

Please keep to the below structure.

Name: The name of the capital city

Location: Where it is based

Vibe: 2-3 words to describe its vibe

Economy: Main industries

"""

scifi_agent = create_agent(
    # model="gpt-5-nano",
    model = model,
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# Name: Luna Nova
#
# Location: Within the vast, multi-tiered biospheres constructed inside the illuminated rim of Shackleton Crater, at the Moon's South Pole.
#
# Vibe: Sleek, Resilient, Visionary
#
# Economy: Helium-3 fusion fuel refinement, advanced zero-gravity manufacturing, astrodynamics research and development, specialized tourism, and sustainable closed-loop agricultural systems.

# %%
pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the moon?", additional_kwargs={}, response_metadata={}, id='1e66968d-560b-4a8b-8738-c10954b90ca8'),
#               AIMessage(content="Name: Luna Nova\n\nLocation: Within the vast, multi-tiered biospheres constructed inside the illuminated rim of Shackleton Crater, at the Moon's South Pole.\n\nVibe: Sleek, Resilient, Visionary\n\nEconomy: Helium-3 fusion fuel refinement, advanced zero-gravity manufacturing, astrodynamics research and development, specialized tourism, and sustainable closed-loop agricultural systems.", additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019b94c5-d6a3-7f73-9d7a-eb5f4c1831bc-0', usage_metadata={'input_tokens': 71, 'output_tokens': 396, 'total_tokens': 467, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 316}})]}

# %% [markdown]
# ## Structured output

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage
from pydantic import BaseModel

class CapitalInfo(BaseModel):
    name: str
    location: str
    vibe: str
    economy: str

agent = create_agent(
    model='gpt-5-nano',
    # model=model,
    system_prompt="You are a science fiction writer, create a capital city at the users request.",
    response_format=CapitalInfo
)

question = HumanMessage(content="What is the capital of The Moon?")

response = agent.invoke(
    {"messages": [question]}
)

response["structured_response"]
# Out:
# CapitalInfo(name='Lunaris Prime', location='Southern lunar highlands, on the rim of Clavius Crater (Moon)', vibe='A gleaming, glass-domed metropolis of science and governance—neon-lit plazas, orbital transit rings, and a culture built on knowledge, collaboration, and rugged optimism.', economy='Water ice extraction, helium-3 mining, lunar construction and manufacturing, R&D in life-support and propulsion, and lunar tourism/education.')

# %%
pprint(response)
# Out:
# {'messages': [HumanMessage(content='What is the capital of The Moon?', additional_kwargs={}, response_metadata={}, id='49c6389f-db9c-48f4-ac50-cb70b20df72f'),
#               AIMessage(content='{"name":"Lunaris Prime","location":"Southern lunar highlands, on the rim of Clavius Crater (Moon)","vibe":"A gleaming, glass-domed metropolis of science and governance—neon-lit plazas, orbital transit rings, and a culture built on knowledge, collaboration, and rugged optimism.","economy":"Water ice extraction, helium-3 mining, lunar construction and manufacturing, R&D in life-support and propulsion, and lunar tourism/education."}', additional_kwargs={'parsed': None, 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 1519, 'prompt_tokens': 193, 'total_tokens': 1712, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 1408, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-Cv76ZbRH7lI6j5kZ15dKgfti3MdKh', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b94cd-4fea-7b23-ab2a-c10d7935ae86-0', usage_metadata={'input_tokens': 193, 'output_tokens': 1519, 'total_tokens': 1712, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 1408}})],
#  'structured_response': CapitalInfo(name='Lunaris Prime', location='Southern lunar highlands, on the rim of Clavius Crater (Moon)', vibe='A gleaming, glass-domed metropolis of science and governance—neon-lit plazas, orbital transit rings, and a culture built on knowledge, collaboration, and rugged optimism.', economy='Water ice extraction, helium-3 mining, lunar construction and manufacturing, R&D in life-support and propulsion, and lunar tourism/education.')}

# %%
pprint(response['structured_response'])
# Out:
# CapitalInfo(name='Lunaris Prime', location='Southern lunar highlands, on the rim of Clavius Crater (Moon)', vibe='A gleaming, glass-domed metropolis of science and governance—neon-lit plazas, orbital transit rings, and a culture built on knowledge, collaboration, and rugged optimism.', economy='Water ice extraction, helium-3 mining, lunar construction and manufacturing, R&D in life-support and propulsion, and lunar tourism/education.')

# %%
response["structured_response"].name
# Out:
# 'Lunaris Prime'

# %%
capital_info = response["structured_response"]

capital_name = capital_info.name
capital_location = capital_info.location

print(f"{capital_name} is a city located at {capital_location}")
