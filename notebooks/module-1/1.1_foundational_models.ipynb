# %%
from dotenv import load_dotenv

load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ## Initialising and invoking a model

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(model="gpt-5-nano")

# prices for openai/gemini tokens
# https://platform.openai.com/docs/pricing
# https://ai.google.dev/gemini-api/docs/pricing#gemini-2.5-pro

# %%
response = model.invoke("What's the capital of the Moon?")

response
# Out:
# AIMessage(content='There isn’t one. The Moon isn’t a country or government, so it has no capital. If humans ever establish a lunar settlement or nation, any capital would be decided by its future governance. Want a quick refresher on current and planned lunar bases instead?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 446, 'prompt_tokens': 13, 'total_tokens': 459, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 384, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-Cv4Lgl2JVfrG3qs0bPNPu3tJ1Funz', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b942b-a3d6-76d1-b123-72c0b95949e8-0', usage_metadata={'input_tokens': 13, 'output_tokens': 446, 'total_tokens': 459, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 384}})

# %%
print(response.content)
# Out:
# There isn’t one. The Moon isn’t a country or government, so it has no capital. If humans ever establish a lunar settlement or nation, any capital would be decided by its future governance. Want a quick refresher on current and planned lunar bases instead?

# %%
type(response)
# Out:
# langchain_core.messages.ai.AIMessage

# %%
response.response_metadata
# Out:
# {'token_usage': {'completion_tokens': 446,
#   'prompt_tokens': 13,
#   'total_tokens': 459,
#   'completion_tokens_details': {'accepted_prediction_tokens': 0,
#    'audio_tokens': 0,
#    'reasoning_tokens': 384,
#    'rejected_prediction_tokens': 0},
#   'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}},
#  'model_provider': 'openai',
#  'model_name': 'gpt-5-nano-2025-08-07',
#  'system_fingerprint': None,
#  'id': 'chatcmpl-Cv4Lgl2JVfrG3qs0bPNPu3tJ1Funz',
#  'service_tier': 'default',
#  'finish_reason': 'stop',
#  'logprobs': None}

# %%
from pprint import pprint

pprint(response.response_metadata)
# Out:
# {'finish_reason': 'stop',
#  'id': 'chatcmpl-Cv4Lgl2JVfrG3qs0bPNPu3tJ1Funz',
#  'logprobs': None,
#  'model_name': 'gpt-5-nano-2025-08-07',
#  'model_provider': 'openai',
#  'service_tier': 'default',
#  'system_fingerprint': None,
#  'token_usage': {'completion_tokens': 446,
#                  'completion_tokens_details': {'accepted_prediction_tokens': 0,
#                                                'audio_tokens': 0,
#                                                'reasoning_tokens': 384,
#                                                'rejected_prediction_tokens': 0},
#                  'prompt_tokens': 13,
#                  'prompt_tokens_details': {'audio_tokens': 0,
#                                            'cached_tokens': 0},
#                  'total_tokens': 459}}

# %% [markdown]
# ## Customising your Model

# %%
model = init_chat_model(
    model="gpt-5-nano",
    # Kwargs passed to the model:
    temperature=1.0
)

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# There isn’t one. The Moon isn’t a country or government, so it has no capital city. In fiction, authors sometimes invent lunar capitals (e.g., Luna City, Moonbase Alpha), but there’s no real capital today.

# %% [markdown]
# ## Model Providers

# %% [markdown]
# https://docs.langchain.com/oss/python/integrations/chat

# %%
# model = init_chat_model(model="claude-sonnet-4-5")

# response = model.invoke("What's the capital of the Moon?")
# print(response.content)

# %%
# import os
# # os.environ['GOOGLE_API_KEY']
# os.environ.get('GOOGLE_API_KEY')
# GOOGLE_API_KEY=os.environ.get('google_api_key')
# print(GOOGLE_API_KEY)

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# That's a fun question! The Moon doesn't have a capital city like Earth does. It's a celestial body with no human settlements or political structures.
#
# Perhaps you were thinking of a fictional capital from a book or movie? If so, let me know and I can try to help you recall it!

# %% [markdown]
# ## Initialising and invoking an agent

# %%
from langchain.agents import create_agent

agent = create_agent(model=model)

# %%
# agent = create_agent(model="claude-sonnet-4-5")

# %%
# agent = create_agent("gpt-5-nano")

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?")]}
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='589bcc38-379d-4dba-93a4-ce39bb67b8db'),
#               AIMessage(content='The Moon doesn\'t have a capital city in the way Earth\'s countries do. It\'s a celestial body, not a political entity with governments and capitals.\n\nHowever, if we were to imagine a hypothetical scenario where humans established a settlement on the Moon and that settlement became a significant hub, its "capital" might be considered:\n\n*   **The most developed or populated base:** Similar to how a country\'s capital is often its largest or most important city.\n*   **A designated administrative center:** If a lunar government were ever established, they would likely designate a specific location as the capital.\n\nBut as of now, there\'s no such thing as a capital of the Moon.', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019b9471-7331-7f91-89d1-87f29350098d-0', usage_metadata={'input_tokens': 10, 'output_tokens': 144, 'total_tokens': 154, 'input_token_details': {'cache_read': 0}})]}

# %%
type(response)
# Out:
# dict

# %%
print(response['messages'][-1].content)
# Out:
# The Moon doesn't have a capital city in the way Earth's countries do. It's a celestial body, not a political entity with governments and capitals.
#
# However, if we were to imagine a hypothetical scenario where humans established a settlement on the Moon and that settlement became a significant hub, its "capital" might be considered:
#
# *   **The most developed or populated base:** Similar to how a country's capital is often its largest or most important city.
# *   **A designated administrative center:** If a lunar government were ever established, they would likely designate a specific location as the capital.
#
# But as of now, there's no such thing as a capital of the Moon.

# %%
# pprint(response.response_metadata)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 pprint(response.response_metadata)
#
# AttributeError: 'dict' object has no attribute 'response_metadata'

# %%
from langchain.messages import AIMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?"),
    AIMessage(content="The capital of the Moon is Luna City."),
    HumanMessage(content="Interesting, tell me more about Luna City")]}
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='4654150d-a7ef-4bba-b852-cbc488a4671c'),
#               AIMessage(content='The capital of the Moon is Luna City.', additional_kwargs={}, response_metadata={}, id='e82bbc36-251c-43b0-9d6d-1abe0dea058b'),
#               HumanMessage(content='Interesting, tell me more about Luna City', additional_kwargs={}, response_metadata={}, id='8d32af21-ffac-4a09-a6ac-8f528ecd5f92'),
#               AIMessage(content="Luna City is the first and only city on the Moon. It's a bustling metropolis, home to a diverse population of humans and aliens. The city is renowned for its advanced technology, stunning architecture, and vibrant culture.\n\nHere are some key features and aspects of Luna City:\n\n**Location and Structure:**\n\n*   **Underground Haven:** Much of Luna City is built underground, providing protection from the harsh lunar environment (radiation, extreme temperatures, and micrometeoroids). Large, transparent domes or reinforced canopies are often used to create simulated surface environments within these underground structures, allowing residents to experience a semblance of open sky.\n*   **Domed Sections:** Some surface areas are covered by enormous, pressurized domes that create breathable atmospheres and controlled environments. These might house parks, recreational areas, or even small agricultural zones.\n*   **Verticality:** Given limited surface area and the desire to maximize living and working space, Luna City often features impressive vertical construction, with skyscrapers and multi-level complexes.\n\n**Inhabitants:**\n\n*   **Humans:** The pioneers and primary builders of Luna City, driven by exploration, scientific research, resource extraction, and seeking new opportunities.\n*   **Aliens:** Luna City has become a hub for interstellar trade and diplomacy, attracting various alien species. This has led to a unique cultural blend, with different alien physiologies and customs influencing the city's development. Imagine seeing beings from different star systems mingling in the markets or attending cultural events.\n\n**Economy and Industry:**\n\n*   **Resource Extraction:** The Moon is rich in valuable resources like Helium-3 (a potential fuel for fusion reactors), rare earth metals, and silicates. Luna City serves as the operational base for mining and processing these materials.\n*   **Scientific Research:** Its proximity to Earth and unique environment make the Moon an ideal location for scientific research, from astronomy and geology to studying the effects of low gravity on biology.\n*   **Interstellar Trade Hub:** Luna City's strategic location makes it a crucial point for trade between Earth and other interstellar civilizations. This brings exotic goods, advanced technologies, and a constant flow of visitors.\n*   **Tourism:** The novelty of visiting the Moon has made Luna City a popular tourist destination for Earthlings and other beings seeking unique experiences.\n\n**Culture and Lifestyle:**\n\n*   **Fusion of Cultures:** The presence of humans and various alien species creates a rich tapestry of traditions, languages, and art forms. You might hear alien languages spoken on the streets alongside human ones, and see unique alien art displayed in galleries.\n*   **Adaptation to Low Gravity:** Life on the Moon means adapting to one-sixth Earth's gravity. This has influenced architecture, transportation (think personal levitation devices or specialized vehicles), and even recreational activities (lunar acrobatics!).\n*   **Technological Marvels:** Luna City is a showcase of cutting-edge technology, from advanced life support systems and self-sustaining ecosystems to sophisticated communication networks and personal AI companions.\n*   **Unique Entertainment:** Expect entertainment venues that cater to diverse species, perhaps with zero-gravity performance art, bioluminescent displays, or holographic concerts.\n\n**Governance and Society:**\n\n*   **Council or Federation:** The governance structure likely involves a council or a federation representing different factions or species, ensuring fair representation and managing the city's complex needs.\n*   **Challenges:** As a frontier city, Luna City likely faces challenges related to resource management, maintaining environmental stability, interspecies relations, and potential external threats.\n\n**In essence, Luna City is a sym ...

# %%
print(response['messages'][-1].content)
# Out:
# Luna City is the first and only city on the Moon. It's a bustling metropolis, home to a diverse population of humans and aliens. The city is renowned for its advanced technology, stunning architecture, and vibrant culture.
#
# Here are some key features and aspects of Luna City:
#
# **Location and Structure:**
#
# *   **Underground Haven:** Much of Luna City is built underground, providing protection from the harsh lunar environment (radiation, extreme temperatures, and micrometeoroids). Large, transparent domes or reinforced canopies are often used to create simulated surface environments within these underground structures, allowing residents to experience a semblance of open sky.
# *   **Domed Sections:** Some surface areas are covered by enormous, pressurized domes that create breathable atmospheres and controlled environments. These might house parks, recreational areas, or even small agricultural zones.
# *   **Verticality:** Given limited surface area and the desire to maximize living and working space, Luna City often features impressive vertical construction, with skyscrapers and multi-level complexes.
#
# **Inhabitants:**
#
# *   **Humans:** The pioneers and primary builders of Luna City, driven by exploration, scientific research, resource extraction, and seeking new opportunities.
# *   **Aliens:** Luna City has become a hub for interstellar trade and diplomacy, attracting various alien species. This has led to a unique cultural blend, with different alien physiologies and customs influencing the city's development. Imagine seeing beings from different star systems mingling in the markets or attending cultural events.
#
# **Economy and Industry:**
#
# *   **Resource Extraction:** The Moon is rich in valuable resources like Helium-3 (a potential fuel for fusion reactors), rare earth metals, and silicates. Luna City serves as the operational base for mining and processing these materials.
# *   **Scientific Research:** Its proximity to Earth and unique environment make the Moon an ideal location for scientific research, from astronomy and geology to studying the effects of low gravity on biology.
# *   **Interstellar Trade Hub:** Luna City's strategic location makes it a crucial point for trade between Earth and other interstellar civilizations. This brings exotic goods, advanced technologies, and a constant flow of visitors.
# *   **Tourism:** The novelty of visiting the Moon has made Luna City a popular tourist destination for Earthlings and other beings seeking unique experiences.
#
# **Culture and Lifestyle:**
#
# *   **Fusion of Cultures:** The presence of humans and various alien species creates a rich tapestry of traditions, languages, and art forms. You might hear alien languages spoken on the streets alongside human ones, and see unique alien art displayed in galleries.
# *   **Adaptation to Low Gravity:** Life on the Moon means adapting to one-sixth Earth's gravity. This has influenced architecture, transportation (think personal levitation devices or specialized vehicles), and even recreational activities (lunar acrobatics!).
# *   **Technological Marvels:** Luna City is a showcase of cutting-edge technology, from advanced life support systems and self-sustaining ecosystems to sophisticated communication networks and personal AI companions.
# *   **Unique Entertainment:** Expect entertainment venues that cater to diverse species, perhaps with zero-gravity performance art, bioluminescent displays, or holographic concerts.
#
# **Governance and Society:**
#
# *   **Council or Federation:** The governance structure likely involves a council or a federation representing different factions or species, ensuring fair representation and managing the city's complex needs.
# *   **Challenges:** As a frontier city, Luna City likely faces challenges related to resource management, maintaining environmental stability, interspecies relations, and potential external threats.
#
# **In essence, Luna City is a symbol of humanity's reach beyond Earth and a testament to cooperation and innovation in a truly alien environment.** It's a place where the future is being built, one crater at a time.

# %% [markdown]
# ## Streaming Output

# %%
for token, metadata in agent.stream(
    {"messages": [HumanMessage(content="Tell me all about Luna City, the capital of the Moon")]},
    stream_mode="messages"
):

    # token is a message chunk with token content
    # metadata contains which node produced the token
    
    if token.content:  # Check if there's actual content
        print(token.content, end="", flush=True)  # Print token
# Out:
# While Luna City is a popular and evocative concept in science fiction, it's important to clarify that **there is currently no actual Luna City, nor is there a permanent human settlement on the Moon that functions as a capital.**
#
# However, the idea of Luna City is rich with possibilities and has been explored extensively in literature and thought experiments. If we imagine Luna City as it might exist in a future where humanity has established a thriving lunar presence, here's what we can envision:
#
# ## The Dream of Luna City: A Capital on the Moon
#
# Luna City, as a concept, represents the apex of lunar civilization. It would be more than just a collection of habitats; it would be a center of governance, commerce, culture, and scientific advancement. Here's a breakdown of its potential aspects:
#
# **1. Location and Structure:**
#
# *   **Shielded Habitation:** The primary concern for any lunar city would be protection from the harsh lunar environment: vacuum, extreme temperature fluctuations, and radiation (cosmic rays and solar flares). Luna City would likely be:
#     *   **Subterranean:** Buried beneath the lunar regolith (soil) for natural shielding. Lava tubes, naturally formed underground caverns, would be ideal locations.
#     *   **Domed:** Large, transparent, and incredibly strong domes made of advanced materials could cover surface settlements, providing protection and allowing for natural sunlight (filtered and controlled).
#     *   **Modular and Expandable:** Built in sections, allowing for growth and adaptation as the population increases.
# *   **Strategic Placement:** Luna City would likely be located near resources like water ice (found in shadowed craters at the poles) and in areas with relatively stable temperatures or access to abundant solar power. The polar regions, with their permanent shadows and near-constant sunlight, are prime candidates.
# *   **Underground Infrastructure:** A complex network of tunnels, transit systems, and utility conduits would connect different sections of the city, both horizontally and vertically.
#
# **2. Governance and Society:**
#
# *   **Unique Political System:** The governance of Luna City would likely be a fascinating experiment.
#     *   **Democracy/Republic:** A representative democracy, perhaps with unique electoral systems to account for the challenges of a space-faring society.
#     *   **Technocracy:** Given the technical expertise required for survival and prosperity, a system heavily influenced by scientists and engineers is plausible.
#     *   **International Consortium:** If established by multiple nations, it could be a joint administration.
# *   **Lunar Identity:** Over generations, a distinct "Lunar" culture and identity would emerge, shaped by the unique environment, the challenges of living off-world, and a shared pioneering spirit.
# *   **Resource Management:** Strict resource management would be paramount. Water, air, and energy would be precious commodities, leading to highly efficient recycling and sustainable practices.
# *   **Law and Order:** A specialized legal system would address issues unique to a lunar environment, such as habitat integrity, resource allocation disputes, and potential inter-colony relations.
#
# **3. Economy and Industry:**
#
# *   **Resource Extraction:** The Moon offers unique resources:
#     *   **Helium-3:** A potential fuel source for future fusion reactors on Earth.
#     *   **Rare Earth Elements:** Crucial for advanced technologies.
#     *   **Water Ice:** For life support, agriculture, and rocket propellant.
# *   **Scientific Research Hub:** Luna City would be a prime location for astronomical observation (due to the lack of atmosphere and light pollution), geology, and fundamental physics research.
# *   **Manufacturing and Fabrication:** Utilizing local resources and advanced 3D printing technologies to create tools, spare parts, and even new structures.
# *   **Tourism and Hospitality:** As travel becomes more accessible, Luna City could become a unique tourist destination.
# *   **Gateway to Space:** Potentially serving as a staging point for further space exploration and colonization within the solar system.
#
# **4. Lifestyle and Culture:**
#
# *   **Controlled Environments:** Life would be lived within carefully controlled habitats. Artificial sunlight, simulated gravity (through rotation or other technologies), and engineered ecosystems would be common.
# *   **Emphasis on Community:** Survival and prosperity would rely heavily on cooperation and a strong sense of community.
# *   **Unique Arts and Entertainment:** Lunar art, music, and literature would reflect the experience of living on another world, inspired by the stark beauty of the lunar landscape and the challenges of existence.
# *   **Technological Integration:** Advanced technology would be seamlessly integrated into daily life, from personal assistants to sophisticated life support systems.
# *   **Connection to Earth:** While developing its own identity, Luna City would likely maintain strong ties to Earth for trade, cultural exchange, and potentially as a place of origin for many of its citizens.
#
# **5. Challenges and Considerations:**
#
# *   **Psychological Impact:** The long-term effects of living in enclosed environments with limited natural stimulation and a constant awareness of danger would need to be addressed.
# *   **Physiological Adaptation:** Understanding and mitigating the effects of reduced gravity on human physiology would be crucial.
# *   **Self-Sufficiency:** Achieving complete self-sufficiency from Earth would be a monumental undertaking.
# *   **Ethical Dilemmas:** Questions of resource ownership, governance, and the definition of "lunar citizen" would arise.
# *   **Cost and Infrastructure:** Building and maintaining such a city would require unprecedented investment and technological innovation.
#
# **In Science Fiction:**
#
# Luna City is a recurring motif in science fiction, often depicted as a gleaming metropolis, a gritty frontier town, or a sophisticated scientific outpost. Examples include:
#
# *   **"The Moon Is a Harsh Mistress" by Robert A. Heinlein:** Where Luna is a penal colony and a burgeoning independent nation with a distinct culture.
# *   **"2001: A Space Odyssey" by Arthur C. Clarke:** Features a lunar research base that plays a pivotal role.
# *   **"Oblivion" (film):** Depicts a future where Earth is abandoned and the Moon becomes a vital hub.
#
# **The Future of Lunar Cities:**
#
# While Luna City remains a figment of our imagination for now, the dream of human settlement on the Moon is a tangible goal. The Artemis program by NASA and international partners aims to establish a sustained human presence on the lunar surface, which could, in the distant future, evolve into something akin to a "capital" for our lunar endeavors.
#
# So, while there's no "Luna City" today, the concept fuels our aspirations for a future where humanity ventures beyond Earth and builds new homes among the stars.
